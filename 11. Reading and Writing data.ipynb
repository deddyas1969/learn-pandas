# %%
import pandas as pd

# %%
df = pd.read_csv('D:/NUMPYPANDA/env/datalagi/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('D:/NUMPYPANDA/env/datalagi/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_columns',85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %% [markdown]
# #### menampilkan data negara India

# %%
filt = (df['Country'] == 'India')

# %%
india_df = df.loc[filt]

# %%
india_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %% [markdown]
# #### export data diatas menjadi csv file

# %%
india_df.to_csv('D:/NUMPYPANDA/env/datalagi/survey_results_india.csv')

# %% [markdown]
# #### export data menjadi tsv

# %%
india_df.to_csv('D:/NUMPYPANDA/env/datalagi/survey_results_india.tsv', sep='\t')

# %% [markdown]
# #### export data menjadi excel (xlsx)

# %% [markdown]
# ![image.png](attachment:1d6d1ffb-b76e-4507-90d1-f6b6d5c8fecd.png)

# %% [markdown]
# #### hasil instal akan sbb

# %% [markdown]
# ![image.png](attachment:42e21fde-7164-4b2b-b46c-4e95a5454e74.png)

# %% [markdown]
# sekarang kita test ya, apakah bisa berjalan

# %%
india_df.to_excel('D:/NUMPYPANDA/env/datalagi/survey_results_india.xlsx')

# %% [markdown]
# #### export data menjadi format JSON

# %%
india_df.to_json('D:/NUMPYPANDA/env/datalagi/survey_results_india.json', orient='records',lines=True)

# %% [markdown]
# #### Export data menjadi SQL

# %% [markdown]
# #### install dulu pip nya, pakai CMD.exe Prompt di anaconda.navigator

# %% [markdown]
# ![image.png](attachment:4e32f5fc-be0a-4997-a452-8bac7863aa99.png)

# %% [markdown]
# Sama ini juga

# %% [markdown]
# ![image.png](attachment:8aa4a647-e937-4f2a-b97b-f280cbce9955.png)

# %% [markdown]
# hasilnya

# %% [markdown]
# ![image.png](attachment:3960b4a9-dcff-41d5-8baa-2b6773166a18.png)

# %% [markdown]
# ![image.png](attachment:fc489d2a-fad3-4452-ba6f-841e4ab2223e.png)
