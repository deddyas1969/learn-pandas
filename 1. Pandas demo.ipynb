# %%
import pandas as pd

# %% [markdown]
# #### nama filenya harus pakai "/" ya , aslinya khan "D:\"
# #### untuk mengambil filenya, buka explorer, lalu pada file yang akan di ambil, klik kanan lalu copy as path
# #### baru kemudian paste ke jupyter notebook

# %%
df = pd.read_csv('D:/NUMPYPANDA/env/datalagi/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# #### Untuk mengetahui jumlah baris dan kolom dari filenya

# %%
df.shape
# Out:
# (88883, 85)

# %% [markdown]
# #### Mengetahui informasi jenis data dari masing-masing kolom

# %%
df.info()

#### Merubah setting jumlah kolom yang ditampilkan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %% [markdown]
# #### kita ingin menampilkan tabel dengan kolom 85

# %% [markdown]
# #### menampilkan seluruh kolom schema , dengan cara buat fungsi max_rows, kalau yg max_columns hanya sepenggal saja

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %% [markdown]
# #### setelah itu kita kembali ke atas yg ada fungsi df, untuk menjalankan ulang fungsi tsb

# %%
schema_df = pd.read_csv('D:/NUMPYPANDA/env/datalagi/survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# #### menampilkan isi kolom Hobbyist

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %% [markdown]
# #### Mengetahui berapa yang Yes, berapa yang No dari kolom Hobbysit

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# #### mengetahui isi 1 baris full

# %%
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %% [markdown]
# #### Mengetahui lebih dari 1 baris, misalnya baris ke 0 dan ke 5 dan ke 20 misalnya

# %%
df.loc[[0,5,20]]
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 20          21                        I code primarily as a hobby      Yes
#
#                    OpenSourcer  \
# 0                        Never
# 5                        Never
# 20  Once a month or more often
#
#                                            OpenSource  \
# 0   The quality of OSS and closed source software ...
# 5   The quality of OSS and closed source software ...
# 20  OSS is, on average, of HIGHER quality than pro...
#
#                                 Employment         Country Student  \
# 0   Not employed, and not looking for work  United Kingdom      No
# 5                       Employed full-time          Canada      No
# 20                                     NaN          Canada     NaN
#
# ...

# %% [markdown]
# #### Melihat isi dari 2 kolom dari baris ke 0, 5, dan 20

# %% [markdown]
# #### Jadi dalam penulisan nama kolom TIDAK BOLEH SALAH KETIK

# %%
df.loc[[1,5,20],['Hobbyist','Student']]
# Out:
#    Hobbyist         Student
# 1        No  Yes, full-time
# 5       Yes              No
# 20      Yes             NaN

# %% [markdown]
# #### boleh juga penulisannya memakai RANGE,
# #### baris mulai dari index 0 sampai 2 dan kolom dari Hobbyist sampai kolom Employment

# %%
df.loc[0:2,'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# #### Kita akan merubah index di tabel utama menjadi kolom Respondent

# %%
df = pd.read_csv('D:/NUMPYPANDA/env/datalagi/survey_results_public.csv', index_col='Respondent')
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %% [markdown]
# #### kita juga akan merubah index di tabel schema ,

# %%
schema_df = pd.read_csv('D:/NUMPYPANDA/env/datalagi/survey_results_schema.csv', index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %% [markdown]
#  #### kita ingin tahu isi kolom "QuestionText" dengan mengacu dari column indexnya

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %% [markdown]
# #### Melihat isi kolom "QuestionText" secara penuh

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %% [markdown]
# #### Untuk men sortir seauai abjad indek nya

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# #### bisa juga diisi dengan

# %%
schema_df.sort_index(ascending=True)
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# #### Untuk menampilkan urutan sebaliknya

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %% [markdown]
# #### Penerapan FILTERING dari pelajaran ke 4

# %% [markdown]
# #### mencari yang memiliki penghasilan di atas 7000, kolom penghasilan ada di kolom yg bernama "ConvertedComp"

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %% [markdown]
# #### kita membuat Data frame nya dulu

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# #### kita ingin menampilkan kolom dengan filter "Country", "Languageworkedwith" dan "convertedcomp"

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %% [markdown]
# #### KIta ingin mem filter berdasarkan Negara

# %%
negara = ['United States','Canada','United Kingdom']
filt = df['Country'].isin(negara)

# %%
df.loc[filt,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 12               Canada
# 13        United States
#               ...
# 85182            Canada
# 85642     United States
# 85961    United Kingdom
# 88282     United States
# 88377            Canada
# Name: Country, Length: 30081, dtype: object

# %% [markdown]
# #### menampilkan kolom LanguageWorkedWith

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %% [markdown]
# #### dari hasil di atas, kita ingin menampilkan ada bahasa python yang di gunakan, ada berapa orang

# %% [markdown]
# #### untuk menghapus NaN, kita gunakan na=False

# %%
bahasa = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[bahasa,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# #### Disini setelah kita beri perintah na=False, maka tabel akan berisi False buat yang berisi NaN

# %%
bahasa
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %% [markdown]
# ### Penerapan Updating Rows and Columns dari pelajaran ke 5

# %% [markdown]
# #### mengubah kolom header "ConvertedComp" , menjadi Salary USD

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'})
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# #### kita tambahkan inplace=True, yang artinya data di update, kalau tidak maka hanya akan membuat copy saja,

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %% [markdown]
# #### kita buka isi kolom Hobbyist ya

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %% [markdown]
# #### type datanya khan object, kita akan mengganti menjadi boolean Yes typenya True; dan No type nya False

# %% [markdown]
# #### ternyata di pandas penamaan "type data" beda dengan python, dan numpy

# %% [markdown]
# ![tabelpandas.png](attachment:8004a2ac-5124-4995-b7c1-fb4f46450131.png)

# %% [markdown]
# #### ini link penting untuk mengenal type data dan bagaimana merubah type nya agar tepat pakai

# %% [markdown]
# https://pbpython.com/pandas_dtypes.html

# %% [markdown]
# #### kita lanjutkan, untuk mengganti Yes jadi True dan No jadi False

# %% [markdown]
# #### jadi intinya, kita harus cek dan ganti kalau type datanya ga sesuai

# %%
df['Hobbyist'].map({'Yes' : True,'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %% [markdown]
# ### selain memakai method "map", bisa juga diganti dengan method "replace"

# %% [markdown]
# ##### tadi di atas khan kita mengupdate isi kolom dengan
# ##### df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %% [markdown]
# #### kita updatekan dengan cara lain

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes' : True,'No': False})

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ### Penarapan pelajaran 7. Sorting data

# %%
df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %% [markdown]
# #### kita akan men sort negara apa saja yang ikut survey ini

# %%
df.sort_values(by='Country')
# Out:
#                                 MainBranch  Hobbyist              OpenSourcer  \
# Respondent
# 39258       I am a developer by profession      True  Less than once per year
# 63129       I am a developer by profession      True                    Never
# 85715       I am a developer by profession     False  Less than once per year
# 50767       I am a developer by profession     False  Less than once per year
# 2782                                   NaN      True  Less than once per year
# ...                                    ...       ...                      ...
# 88062                                  NaN     False                    Never
# 88076                                  NaN     False                    Never
# 88601                                  NaN     False                    Never
# 88802                                  NaN     False                    Never
# 88816                                  NaN     False                    Never
#
# ...

# %% [markdown]
# #### kita hanya ingin menampilkan kolom negara saja

# %%
df['Country'].head(100)
# Out:
# Respondent
# 1              United Kingdom
# 2      Bosnia and Herzegovina
# 3                    Thailand
# 4               United States
# 5                     Ukraine
#                 ...
# 96                     Canada
# 97              United States
# 98     Bosnia and Herzegovina
# 99                      India
# 100                    Canada
# Name: Country, Length: 100, dtype: object

# %% [markdown]
# #### Tampaknya tidak ter sort dengan baik ya, kita buat permanen dulu

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(100)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
#             ...
# 39106        Albania
# 70632        Albania
# 27637        Albania
# 47133        Albania
# 25109        Albania
# Name: Country, Length: 100, dtype: object

# %% [markdown]
# #### Kita sort berdasarkan kolom Country dan kolom

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 26340       Afghanistan        NaN
# 86932       Afghanistan        NaN
# 85825       Afghanistan        NaN
# 7085        Afghanistan    14364.0
# 7353        Afghanistan        NaN
# 87091       Afghanistan        NaN
# ...

# %% [markdown]
# #### Kita ingin men sort secara ascending (0 ke 9) (a ke z) untuk kolom Country

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True,False], inplace=True)

# %% [markdown]
# #### ini artinya ascending (a ke z) untuk Country, tapi desc (9 ke 0) untuk SalaryUSD, hapalin lho ya ini

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# ...

# %% [markdown]
# #### Kita ingin tahu 10 salary tertinggi

# %%
df['SalaryUSD'].nlargest(15)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# 84390    2000000.0
# 2940     2000000.0
# 3133     2000000.0
# 78960    2000000.0
# 3120     2000000.0
# Name: SalaryUSD, dtype: float64

# %% [markdown]
# #### kita ingin tahu lebih detail ttg ke 15 orang ini

# %%
df.nlargest(15,'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
# 84390                          I am a developer by profession      True
# 2940                           I am a developer by profession      True
# ...

# %% [markdown]
# #### Penerapan lesson 8 Grouping & Aggregation (sum, mean, average dsb)

# %% [markdown]
# #### menampilkan kolom SalaryUSD

# %%
df['SalaryUSD'].head(15)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# 28638          0.0
# 722            0.0
# 85715          NaN
# 50767          NaN
# 2782           NaN
# Name: SalaryUSD, dtype: float64

# %% [markdown]
# #### mencari median salary

# %% [markdown]
# #### Median adalah angka tengah dalam daftar angka yang diurutkan secara menaik atau menurun dan dapat lebih
# #### menggambarkan kumpulan data daripada rata-rata.
# #### Median adalah titik di atas dan di bawah tempat 50% data yang diamati berada sehingga mewakili titik tengah data.

# %%
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %% [markdown]
# #### pada baris 50% sama artinya dengan median

# %%
df['SalaryUSD'].count()
# Out:
# 55823

# %% [markdown]
# #### jumlah seluruh baris khan ada 88883 rows, yg isi salary hanya 55823, artinya hanya 37 % yang isi

# %%
df['Hobbyist']
# Out:
# Respondent
# 63129     True
# 50499     True
# 39258     True
# 58450     True
# 7085      True
#          ...
# 88062    False
# 88076    False
# 88601    False
# 88802    False
# 88816    False
# Name: Hobbyist, Length: 88883, dtype: bool

# %% [markdown]
# #### Kita ingin tahu berapa yang jawab yes, berapa yang jawab no

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# True     71257
# False    17626
# Name: count, dtype: int64

# %% [markdown]
# #### Kita ingin mengetahui berapa persen yang jawab Yes atau True

# %%
df['Hobbyist'].value_counts('True')*100
# Out:
# Hobbyist
# True     80.169436
# False    19.830564
# Name: proportion, dtype: float64

# %% [markdown]
# #### sekarang kita periksa ya apakah yg isi kolom "Salary" benar 37 %

# %%
df['SalaryUSD'].count()
# Out:
# 55823

# %%
((88883-df['SalaryUSD'].count())/88883)*100
# Out:
# 37.194964166376025

# %% [markdown]
# #### Kita ingin lihat lagi nama-nama kolom apa

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc',
#        'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow',
#        'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# kita ingin mengetahui social media apa saja yang digunakan

# %%
df['SocialMedia']
# Out:
# Respondent
# 63129    I don't use social media
# 50499                    WhatsApp
# 39258                    Facebook
# 58450                    Facebook
# 7085                    Instagram
#                    ...
# 88062                         NaN
# 88076                         NaN
# 88601                         NaN
# 88802                         NaN
# 88816                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %% [markdown]
# #### Kita lihat ulang lagi pertanyaan apa saja yg ada di tabel schema

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %% [markdown]
# #### untuk kolom social media kita lihat ulang lagi pertanyaannya

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %% [markdown]
# #### mengetahui berapa persent yang menggunakan masing-masing social media

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %% [markdown]
# ### jadi value_count gunanya untuk menghitung berapa kali kemunculan

# %%
(df['SocialMedia'].value_counts(normalize=True))*100
# Out:
# SocialMedia
# Reddit                      17.023343
# YouTube                     16.379076
# WhatsApp                    15.807051
# Facebook                    15.606902
# Twitter                     13.498822
# Instagram                    7.414996
# I don't use social media     6.577685
# LinkedIn                     5.330602
# WeChat 微信                    0.789938
# Snapchat                     0.743750
# VK ВКонта́кте                0.714142
# Weibo 新浪微博                   0.066322
# Youku Tudou 优酷               0.024871
# Hello                        0.022502
# Name: proportion, dtype: float64

# %% [markdown]
# #### penjelasan tentang normalize=True dan teman2 nya

# %% [markdown]
# ![normalize 1.png](attachment:e02786b1-8bc6-41e1-bd2c-47c4367605d8.png)

# %% [markdown]
# ![normalize 2.png](attachment:4c436a60-6956-43aa-997a-f9d77853ad3e.png)

# %% [markdown]
# '''values count merupakan fungsi yang sering digunakan untuk menghitung frekuensi
#
# atau jumlah kemunculan setiap nilai unik dalam sebuah kolom DataFrame.'''

# %% [markdown]
#  #### Kita rencana akan membuat group Country, namun sebelumnya kita lihat dulu jumlah negara yg ikut survey ini

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# #### kita ingin tahun jumlah dari negara United state

# %%
df.groupby('Country')

# %% [markdown]
# #### Kita namakan fungsi diatas dengan country_grp

# %%
country_grp = df.groupby('Country')

# %% [markdown]
# #### dari sini baru kita lihat survey yang dari negara United States

# %%
country_grp.get_group('United States')
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 2940        I am a developer by profession      True
# 3133        I am a developer by profession      True
# 78960       I am a developer by profession      True
# 3120        I am a developer by profession      True
# 78853       I am a developer by profession     False
# ...                                    ...       ...
# 32801       I am a developer by profession     False
# 32811       I am a developer by profession     False
# 32886       I am a developer by profession     False
# 68604       I am a developer by profession      True
# 33792       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 2940        I am a developer by profession      True
# 3133        I am a developer by profession      True
# 78960       I am a developer by profession      True
# 3120        I am a developer by profession      True
# 78853       I am a developer by profession     False
# ...                                    ...       ...
# 32801       I am a developer by profession     False
# 32811       I am a developer by profession     False
# 32886       I am a developer by profession     False
# 68604       I am a developer by profession      True
# 33792       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# ...

# %% [markdown]
# #### Selain groupby, kita juga bisa memakai fungsi filter seperti pd pelajaran sebelumnya

# %% [markdown]
# #### Mengetahui jumlah pemakai social media dari suatu negara

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: count, dtype: int64

# %% [markdown]
# #### di atas khan pernah kita buat fungsi country_grp = df.groupby('Country')

# %% [markdown]
# #### yang mengelompokkan berdasarkan negara

# %% [markdown]
# #### kita sekarang akan menghitung jumlah surveyor di negara berdasarkan social media nya

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: count, Length: 1220, dtype: int64

# %% [markdown]
# #### kita ingin menampilkan hingga 50 baris

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %% [markdown]
# #### kita bisa ber main dg fungsi ini lebih lanjut

# %%
country_grp['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: count, dtype: int64

# %% [markdown]
# #### untuk melihat persentasinya, kita tambahkan normalize=True

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: proportion, dtype: float64

# %% [markdown]
# #### di baris ke 71 khan kita sudah buat groupby yaitu "country_grp = df.groupby('Country')"

# %% [markdown]
# #### kita sekarang ingin mengetahui gaji di tiap negara

# %%
country_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: SalaryUSD, Length: 179, dtype: float64

# %% [markdown]
# #### kolom Country dianggap sebagai index

# %% [markdown]
# #### jadi sekarang kita ingin mengetahui salary untuk country Germany

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 63016.0

# %% [markdown]
# #### menampilkan median, mean, average untuk salary dari tiap negara

# %%
country_grp['SalaryUSD'].agg(['median','mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %% [markdown]
# #### pelajaran fungsi loc ada di link dibawah ini

# %% [markdown]
# https://www.youtube.com/watch?v=naRQyRZrXCE&t=99s

# %% [markdown]
# #### kita lanjutkan, sekarang kita tambahkan fungsi loc, untuk melihat median dan mean dari satu negara

# %%
country_grp['SalaryUSD'].agg(['median','mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %% [markdown]
# #### Kita bisa juga menggunakan fungsi filter (baris 73) sebagai pengganti groupby

# %%
filt = df['Country'] == 'Canada'
df.loc[filt]['SalaryUSD'].mean()
# Out:
# 134018.56490917146

# %% [markdown]
# #### atau kita tambahkan agregate untuk mengetahui median, mean, count, sum dsb

# %%
filt = df['Country'] == 'Canada'
df.loc[filt]['SalaryUSD'].agg(['median','mean','count','sum'])
# Out:
# median    6.870500e+04
# mean      1.340186e+05
# count     2.257000e+03
# sum       3.024799e+08
# Name: SalaryUSD, dtype: float64

# %% [markdown]
# #### kita akan bahas fungsi filter melanjutkan pelajaran fungsi filter di baris ke 73

# %% [markdown]
# pada pelajaran lalu kita ingin mengetahui kolom "Country" yaitu "United Stated

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 2940        I am a developer by profession      True
# 3133        I am a developer by profession      True
# 78960       I am a developer by profession      True
# 3120        I am a developer by profession      True
# 78853       I am a developer by profession     False
# ...                                    ...       ...
# 32801       I am a developer by profession     False
# 32811       I am a developer by profession     False
# 32886       I am a developer by profession     False
# 68604       I am a developer by profession      True
# 33792       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# ...

# %% [markdown]
# #### Sekarang kita ingin tahu kolom "Country" dan kolom "LanguageWorkedWith" yg bernama "United Stated"

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['LanguageWorkedWith']
# Out:
# Respondent
# 2940                                                C++;Go
# 3133     Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 78960         Bash/Shell/PowerShell;C#;HTML/CSS;Python;SQL
# 3120     Bash/Shell/PowerShell;Clojure;HTML/CSS;Java;Ja...
# 78853    Bash/Shell/PowerShell;C#;F#;HTML/CSS;Java;Java...
#                                ...
# 32801                                 C#;SQL;VBA;Other(s):
# 32811                                          C#;Java;SQL
# 32886    Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 68604    Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 33792                              JavaScript;Python;R;SQL
# Name: LanguageWorkedWith, Length: 20949, dtype: object

# %% [markdown]
# #### mengetahui yang hanya menggunakan python

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 2940     False
# 3133      True
# 78960     True
# 3120      True
# 78853    False
#          ...
# 32801    False
# 32811    False
# 32886     True
# 68604     True
# 33792     True
# Name: LanguageWorkedWith, Length: 20949, dtype: object

# %% [markdown]
# #### Mengetahui jumlah yang menggunakan Python

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 10083

# %%
(10083/20949) * 100
# Out:
# 48.13117571244451

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# File D:\ANACONDABARU\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %% [markdown]
# #### Ternyata ada error untuk itu digunakan lambda

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# #### Untuk mendalami lambda function, ini ada plylist YT nya

# %% [markdown]
# https://www.youtube.com/watch?v=HBR6wqXj2iY&list=PLH6mU1kedUy84TsNa1654qkHjIeZ_wllA

# %% [markdown]
# #### ini ada penjelasan yang lebih mudah dimengerti

# %% [markdown]
# https://www.projectpro.io/article/pandas-apply-lambda/951

# %% [markdown]
# #### di baris ke 69 kita menghitung jumlah responden dg cara

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# #### kita kasi nama variable nya country_respondents

# %%
country_repondents = df['Country'].value_counts()

# %% [markdown]
# #### untuk country yg menggunakan python, kita kasi nama variable nya country_uses_python

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %% [markdown]
# #### Kita akan menggabungkan ke 2 series country_respondents dan country_uses_python

# %%
python_df = pd.concat([country_repondents, country_uses_python])

# %%
python_df
# Out:
# Country
# United States                           20949
# India                                    9061
# Germany                                  5866
# United Kingdom                           5737
# Canada                                   3395
#                                         ...
# Venezuela, Bolivarian Republic of...       28
# Viet Nam                                   78
# Yemen                                       3
# Zambia                                      4
# Zimbabwe                                   14
# Length: 358, dtype: int64

# %% [markdown]
# #### ternyata hasilnya digabung ke bawah, hal ini bukan yg kita harapkan, untuk itu kita tambahkan axis='columns'

# %%
python_df = pd.concat([country_repondents, country_uses_python],axis='columns')
python_df
# Out:
#                                   count  LanguageWorkedWith
# Country
# United States                     20949               10083
# India                              9061                3105
# Germany                            5866                2451
# United Kingdom                     5737                2384
# Canada                             3395                1558
# ...                                 ...                 ...
# North Korea                           1                   0
# Niger                                 1                   1
# Saint Vincent and the Grenadines      1                   0
# Chad                                  1                   0
# Brunei Darussalam                     1                   0
#
# [179 rows x 2 columns]

# %% [markdown]
# #### Kalau kita ingin mengurutkan berdasarkan abjad, maka kita gunakan sort

# %%
python_df = pd.concat([country_repondents, country_uses_python],axis='columns', sort=True)
python_df
# Out:
#                                       count  LanguageWorkedWith
# Country
# Afghanistan                              44                   8
# Albania                                  86                  23
# Algeria                                 134                  40
# Andorra                                   7                   0
# Angola                                    5                   2
# ...                                     ...                 ...
# Venezuela, Bolivarian Republic of...     88                  28
# Viet Nam                                231                  78
# Yemen                                    19                   3
# Zambia                                   12                   4
# Zimbabwe                                 39                  14
#
# [179 rows x 2 columns]

# %% [markdown]
# #### nama kolom yang ada di python_df akan kita ganti

# %%
python_df.rename(columns={'count':'NumRespondents','LanguageWorkedWith':'NumKnowsPython'})
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Country
# Afghanistan                                       44               8
# Albania                                           86              23
# Algeria                                          134              40
# Andorra                                            7               0
# Angola                                             5               2
# ...                                              ...             ...
# Venezuela, Bolivarian Republic of...              88              28
# Viet Nam                                         231              78
# Yemen                                             19               3
# Zambia                                            12               4
# Zimbabwe                                          39              14
#
#                                       PctKnowsPython
# Country
# Afghanistan                                18.181818
# ...

# %% [markdown]
# #### Kita buat permanent

# %%
python_df.rename(columns={'count':'NumRespondents','LanguageWorkedWith':'NumKnowsPython'}, inplace=True)

# %% [markdown]
# #### kita akan menembahkan kolom baru

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents'])*100
python_df
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Country
# Afghanistan                                       44               8
# Albania                                           86              23
# Algeria                                          134              40
# Andorra                                            7               0
# Angola                                             5               2
# ...                                              ...             ...
# Venezuela, Bolivarian Republic of...              88              28
# Viet Nam                                         231              78
# Yemen                                             19               3
# Zambia                                            12               4
# Zimbabwe                                          39              14
#
#                                       PctKnowsPython
# Country
# Afghanistan                                18.181818
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# Dominica                                       1               1
# Niger                                          1               1
# Timor-Leste                                    1               1
# Sao Tome and Principe                          1               1
# Turkmenistan                                   7               6
# ...                                          ...             ...
# Tonga                                          1               0
# North Korea                                    1               0
# Papua New Guinea                               1               0
# Tajikistan                                     7               0
# Lao People's Democratic Republic               3               0
#
#                                   PctKnowsPython
# Country
# Dominica                              100.000000
# Niger                                 100.000000
# ...

# %%
python_df.head(80)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# Dominica                                       1               1
# Niger                                          1               1
# Timor-Leste                                    1               1
# Sao Tome and Principe                          1               1
# Turkmenistan                                   7               6
# Mauritania                                     7               5
# Bahamas                                        3               2
# Guinea                                         3               2
# Guyana                                         3               2
# Uganda                                        72              47
# Iceland                                       49              30
# Namibia                                        5               3
# Benin                                          5               3
# ...
